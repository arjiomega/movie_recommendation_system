# %%
import pandas as pd
from sqlalchemy import create_engine

# Define your PostgreSQL connection details
db_user = 'airflow'
db_password = 'airflow'
db_host = 'localhost'
db_port = '5432'
db_name = 'movie_db'

# Create the connection string
connection_string = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

# Create the engine
engine = create_engine(connection_string)

# %%
df = pd.read_sql_query('select * from "dw_movies"."fact_user_movie_ratings"',con=engine)

# %%
df
# Out:
#                       review_id                           user_id  movie_id  \
# 0      4fa6a0e9760ee34663000762  42f72f87f9c562bb09f6855e07fe0067    107039
# 1      4fb026f6760ee33b55006268  979af578ca9cf9180c484846b6876a07     62213
# 2      4fbdd8c0760ee34fff000fa0  f0e785a989458c79a08c3b8c2b57c36f     79660
# 3      4fc0c860760ee35d79004b1a  dffac62523b0a76a21487497ac6d1b17     57608
# 4      4fcb0d2a19c2955e3c000e35  a86c1fe933a7c6926abfb37b5b71235e     59961
# ...                         ...                               ...       ...
# 20755  6795869325d2980fb023d816  e6cca1354f9411e5989452cbcf7121c2    489999
# 20756  67958bf00e1e0486d62aebd0  9f1d5c6e23b5c2e7f3433d990816b2ce    138843
# 20757  6796817c013209f8918f3065  23d0069ab76e00e160001e1ca2f79bc8    426063
# 20758  6796c46d16f0d960df239910  22eea0243703b7978d73a118c59e19fb   1000837
# 20759  67978d973ae355c4788f3a4a  0a6ea4673dbea8c5c839eacf1603efb9   1097549
#
#       rating                                             review
# 0       None  Winner! — Best Feature, Seattle Lesbian & Gay ...
# 1        8.5  Let's leave it all at the door here. I loved B...
# 2       10.0  Let me first tell you that don't go with any e...
# 3        9.0  Jewel: The Essential Live Songbook\r\n (2008)\...
# 4       None  fast paced action thriller delivers from begin...
# ...      ...                                                ...
# 20755    8.0  *Searching* is one of those movies that grabs ...
# 20756    8.0  <em>'The Conjuring'</em> is an extremely solid...
# 20757    7.0  Was pretty decent movie with beautiful visuals...
# 20758   10.0  Films featuring dark political themes are an a...
# 20759    4.0  Babygirl is the story of high-strung CEO who s...
#
# [20760 rows x 5 columns]
